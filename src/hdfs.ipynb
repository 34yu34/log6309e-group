# %%
from src.hdfsparser import parse_to_csv

parse_to_csv('../data/HDFS', '../data/HDFS', 'HDFS.log')
# Out:
# Parsing file: ../data/HDFS/HDFS.log
# Total lines:  11175629
# Processed 0.0% of log lines.
# Processed 0.0% of log lines.
# Processed 0.0% of log lines.
# Processed 0.0% of log lines.
# Processed 0.0% of log lines.
# Processed 0.1% of log lines.
# Processed 0.1% of log lines.
# Processed 0.1% of log lines.
# Processed 0.1% of log lines.
# Processed 0.1% of log lines.
# Processed 0.1% of log lines.
# Processed 0.1% of log lines.
# Processed 0.1% of log lines.
# Processed 0.1% of log lines.
# Processed 0.1% of log lines.
# Processed 0.1% of log lines.
# Processed 0.2% of log lines.
# Processed 0.2% of log lines.
# Processed 0.2% of log lines.
# Processed 0.2% of log lines.
# Processed 0.2% of log lines.
# Processed 0.2% of log lines.
# Processed 0.2% of log lines.
# Processed 0.2% of log lines.
# Processed 0.2% of log lines.
# Processed 0.2% of log lines.
# Processed 0.2% of log lines.
# Processed 0.3% of log lines.
# Processed 0.3% of log lines.
# Processed 0.3% of log lines.
# ...

# %%
from src.logrep.converter import convert_hdfs_to_splitted_pyz

convert_hdfs_to_splitted_pyz('../data/HDFS/preprocessed/HDFS.npz', '../data/HDFS/HDFS.log.splitted')
# Out:
# Adding 'EventTemplate' on events in groups
# 100%|██████████| 575061/575061 [20:59<00:00, 456.50it/s]
# ====== Grouping summary ======
# Total number of sessions: 575061
# ====== Splitting summary ======
# Total number of test sessions: 172519
# Total number of train sessions: 402542
# Saving to file: ../data/HDFS/HDFS.log.splitted
# Done 🎉

# %%
from src.logrep.ttidfgenerator import generate

generate('../data/HDFS', 'HDFS.log.splitted')

# %%
import numpy as np
loaded = np.load('../data/HDFS/HDFS.log.splitted.npz', allow_pickle=True)
train_x = loaded['x_train'][()]
train_y = loaded['y_train']
test_x = loaded['x_test'][()]
test_y = loaded['y_test']

# %%
train_y
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from tqdm import tqdm

size = max(train_x.keys()) + 1

# Initialize an array of zeros
result_array = np.zeros(size)

# Assign values from the dictionary to the corresponding indices
for key, value in tqdm(train_x.items()):
    result_array[key] = np.array(value)
# Out:
#   0%|          | 0/402542 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only length-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 10
#       8 # Assign values from the dictionary to the corresponding indices
#       9 for key, value in tqdm(train_x.items()):
# ---> 10     result_array[key] = np.array(value)
#
# ValueError: setting an array element with a sequence.

# %%
result_array
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
from src.models.traditional import DecisionTree

decision_tree = DecisionTree()
decision_tree.fit(train_x, train_y)
decision_tree.evaluate(test_x, test_y)
# Out:
# ====== Model summary ======
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 from src.models.traditional import DecisionTree
#       3 decision_tree = DecisionTree()
# ----> 4 decision_tree.fit(train_x, train_y)
#       5 decision_tree.evaluate(test_x, test_y)
#
# File ~/Documents/school/devops/group-assignment/src/models/traditional.py:35, in DecisionTree.fit(self, X, y)
#      29 """
#      30 Arguments
#      31 ---------
#      32     X: ndarray, the event count matrix of shape num_instances-by-num_events
#      33 """
#      34 print('====== Model summary ======')
# ---> 35 self.classifier.fit(X, y)
#
# File ~/Documents/school/devops/group-assignment/venv/lib/python3.9/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
# ...
